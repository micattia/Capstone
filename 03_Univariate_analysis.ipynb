# %% [markdown]
# <a href="https://colab.research.google.com/github/micattia/Capstone/blob/master/03_Univariate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load pandas component for data science
import pandas as pd

#load Apple data 
linkAP1 = 'https://raw.githubusercontent.com/micattia/Capstone/master/AppleFinalData.csv'
dfAPPL = pd.read_csv(linkAP1)
linkAP2 = 'https://raw.githubusercontent.com/micattia/Capstone/master/AppleNewsStock.csv'
dfAPPLnews = pd.read_csv(linkAP2)

#load Microsoft data
linkMS1 = 'https://raw.githubusercontent.com/micattia/Capstone/master/MicrosoftFinalData.csv'
dfMS = pd.read_csv(linkMS1)
linkMS2 = 'https://raw.githubusercontent.com/micattia/Capstone/master/MicrosoftNewsStock.csv'
dfMSnews = pd.read_csv(linkMS2)

# %%
# Changing Some column names for the Microsoft main data frame to:
# 1- removed the space from the Adj Close column, so that it would not give errors with coding
# 2- standarised all columns to start with caps lock.

dfMS = dfMS.rename(index=str, columns={"Adj Close": "Adj_Close", "compound": "Compound", "neg": "Neg", "neu": "Neu", "pos": "Pos"})

# %%
dfMS.head()
# Out:
#         Date   Open   High    Low  ...  Compound    Neg    Neu    Pos
# 0  12/1/2006  29.23  29.30  28.90  ...    0.0000  0.000  0.000  0.000
# 1  12/4/2006  29.23  29.52  29.17  ...   -0.7783  0.137  0.863  0.000
# 2  12/5/2006  29.36  29.40  29.03  ...    0.0000  0.000  0.000  0.000
# 3  12/6/2006  29.10  29.13  28.87  ...    0.9003  0.051  0.847  0.102
# 4  12/7/2006  28.96  29.07  28.81  ...    0.6597  0.000  0.810  0.190
#
# [5 rows x 10 columns]

# %%
#loading required libraries 
#==========================
from statsmodels.graphics.gofplots import qqplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot

# %%
#Testing Normality for Microsoft data set columns [Open]

# Box Plot
dfMS.boxplot( column =['Open'], grid = False) 
# q-q plot
qqplot(dfMS.Open, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Open)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns [High]

# Box Plot
dfMS.boxplot( column =['High'], grid = False) 
# q-q plot
qqplot(dfMS.High, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.High)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns [Low]

# Box Plot
dfMS.boxplot( column =['Low'], grid = False) 
# q-q plot
qqplot(dfMS.Low, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Low)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns [Close]

# Box Plot
dfMS.boxplot( column =['Close'], grid = False) 
# q-q plot
qqplot(dfMS.Close, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Close)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns[Adj_Close]

# Box Plot
dfMS.boxplot( column =['Adj_Close'], grid = False) 
# q-q plot
qqplot(dfMS.Adj_Close, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Adj_Close)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns[Compound]

# Box Plot
dfMS.boxplot( column =['Compound'], grid = False) 
# q-q plot
qqplot(dfMS.Compound, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Compound)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns[Neg]

# Box Plot
dfMS.boxplot( column =['Neg'], grid = False) 
# q-q plot
qqplot(dfMS.Neg, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Neg)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns[Neu]

# Box Plot
dfMS.boxplot( column =['Neu'], grid = False) 
# q-q plot
qqplot(dfMS.Neu, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Neu)
pyplot.show()

# %%
#Testing Normality for Microsoft data set columns[Pos]

# Box Plot
dfMS.boxplot( column =['Pos'], grid = False) 
# q-q plot
qqplot(dfMS.Pos, line='s')
pyplot.show()
# histogram plot
pyplot.hist(dfMS.Pos)
pyplot.show()
